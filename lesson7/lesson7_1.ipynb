# %%
#[]建立list
cities=['台北','台中','高雄']
print(cities)
print(cities[0])
print(cities[1])
print(cities[2])
#print(cities[3])
# Out:
# ['台北', '台中', '高雄']
# 台北
# 台中
# 高雄

# %%
greetings=list("hello world")
print(type(greetings))
print(greetings)
print(greetings[0])
print(greetings[10])
# Out:
# <class 'list'>
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']
# h
# d

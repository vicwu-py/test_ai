# %%
#沒有參數，沒有傳出值
def  sayhello():
    print("hello")
sayhello()
# Out:
# hello

# %%
def sayhello(name): #1個參數沒傳出值
    print(f"您好！{name}！")
sayhello("徐國堂")
# Out:
# 您好！徐國堂！

# %%
def sayhello(name): #1個參數沒傳出值
    return f"您好！{name}!"

print(sayhello ("吳宗哲"))
# Out:
# 您好！吳宗哲!

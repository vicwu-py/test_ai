# %%
#沒有參數，沒有傳出值
def  sayhello():
    print("hello")
sayhello()
# Out:
# hello

# %%
def sayhello(name): #1個參數沒傳出值
    print(f"您好！{name}！")
sayhello("徐國堂")
# Out:
# 您好！徐國堂！

# %%
def sayhello(name): #1個參數沒傳出值
    return f"您好！{name}!"

print(sayhello ("吳宗哲"))
# Out:
# 您好！吳宗哲!

# %%
#計算BMI

def get_bmi(w,h): #2個參數,1個值
    bmi = w / h (h/100) ** 2
    return bmi
def bmi_status(bmi):

    if bmi >35 :
        message="重度肥"
    elif bmi >30:
        message="中度肥"
    elif bmi >27 :
        message="輕度肥胖"
    elif bmi >24 :
        message="過重"
    elif bmi >18.5 :
        message="正常範圍"
    else:
        message="體重過輕"
    return message


#計算bmi
print("====BMI計算=======\n")

height = int(input("請輸入計算(cm):"))
weight = int(input("請輸入體重(kg):"))
bmi= weight / (height/100) ** 2
print(f"您的BMI是{round(bmi,ndigits=2)}")
status= bmi_status(bmi)
print(status)
# Out:
# ====BMI計算=======
#
# 您的BMI是20.37
# 正常範圍

# %%
#猜數字遊戲

import random

target = random.randint(1,100)
target
# Out:
# 75

# %%
#猜數字遊戲

import random

target = random.randint(1,100)
target
# Out:
# 40

# %%
#猜數字遊戲

import random

min=1
max=100
count=0
target = random.randint(min,max)
print("=====猜數字遊戲=====:\n")

while(True):
    count +=1
    keyin = int(input(f"猜數字範圍{min}~{max}"))
    if keyin >=min and keyin<=max:
        if keyin == target:
            print(f"賓果!猜對了，答案是:{target}")
            print(f"您共猜對了{count}次")
            break
        elif keyin > target:
            print("再小一點")
            max = keyin - 1
        elif keyin < target:
            print("再大一點")
            min = keyin + 1 
        print(f"你已經猜對了{count}次")
       
    else:
        print("不在範圍內")
        

print("遊戲結束")
# Out:
# =====猜數字遊戲=====:
#
# 再大一點
# 你已經猜對了1次
# 再大一點
# 你已經猜對了2次
# 再大一點
# 你已經猜對了3次
# 賓果!猜對了，答案是:95
# 您共猜對了4次
# 遊戲結束

# %%
#猜數字遊戲

import random

while (True):
    min=1
    max=100
    count=0
    target = random.randint(min,max)
    print(target)
    print("\n\n=====猜數字遊戲=====:\n")

    while(True):
        count +=1
        keyin = int(input(f"猜數字範圍{min}~{max}"))
        if keyin >=min and keyin<=max:
            if keyin == target:
                print(f"賓果!猜對了，答案是:{target}")
                print(f"您共猜了{count}次")
                break
            elif keyin > target:
                print("再小一點")
                max = keyin - 1
            elif keyin < target:
                print("再大一點")
                min = keyin + 1 
            print(f"你已經猜對了{count}次")
        else:
            print("不在範圍內")

    play_again = input ("請問還要繼續玩嗎?(y,n)?")       
    if play_again =='n':
        break
print("遊戲結束")
# Out:
# 18
#
#
# =====猜數字遊戲=====:
#
# 賓果!猜對了，答案是:18
# 您共猜了1次
# 32
#
#
# =====猜數字遊戲=====:
#
# 賓果!猜對了，答案是:32
# 您共猜了1次
# 遊戲結束

# %%
#猜數字遊戲

import random

def play_game(): #自訂function
    min=1
    max=100
    count=0
    target = random.randint(min,max)
    print(target)
    print("\n\n=====猜數字遊戲=====:\n")

    while(True):
        count +=1
        keyin = int(input(f"猜數字範圍{min}~{max}"))
        if keyin >=min and keyin<=max:
            if keyin == target:
                print(f"賓果!猜對了，答案是:{target}")
                print(f"您共猜了{count}次")
                break
            elif keyin > target:
                print("再小一點")
                max = keyin - 1
            elif keyin < target:
                print("再大一點")
                min = keyin + 1 
            print(f"你已經猜對了{count}次")
        else:
            print("不在範圍內")
while (True):
    play_game()
    play_again = input ("請問還要繼續玩嗎?(y,n)?")       
    if play_again =='n':
        break
# Out:
# 68
#
#
# =====猜數字遊戲=====:
#
# 賓果!猜對了，答案是:68
# 您共猜了1次
# 69
#
#
# =====猜數字遊戲=====:
#
# 賓果!猜對了，答案是:69
# 您共猜了1次
